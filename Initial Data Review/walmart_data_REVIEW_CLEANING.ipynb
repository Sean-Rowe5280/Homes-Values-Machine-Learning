# %%
walmart_store_locaction.csv

# %%
import pandas as pd

# %%
df=pd.read_csv("Resources/walmart_store_locaction.csv.zip")

# %%
df.head()
# Out:
#                         name  \
# 0         Conway Supercenter
# 1       Sikeston Supercenter
# 2      Tahlequah Supercenter
# 3  Mountain Home Supercenter
# 4      Claremore Supercenter
#
#                                                  url          street_address  \
# 0  https://www.walmart.com/store/5/conway-ar/details       1155 Hwy 65 North
# 1  https://www.walmart.com/store/9/sikeston-mo/de...          1303 S Main St
# 2  https://www.walmart.com/store/10/tahlequah-ok/...     2020 S Muskogee Ave
# 3  https://www.walmart.com/store/11/mountain-home...          65 Wal Mart Dr
# 4  https://www.walmart.com/store/12/claremore-ok/...  1500 S Lynn Riggs Blvd
#
#             city state  zip_code country phone_number_1  phone_number_2  \
# 0         Conway    AR     72032      US   501-329-0023             NaN
# 1       Sikeston    MO     63801      US   573-472-3020             NaN
# 2      Tahlequah    OK     74464      US   918-456-8804             NaN
# ...

# %%
df.columns
# Out:
# Index(['name', 'url', 'street_address', 'city', 'state', 'zip_code', 'country',
#        'phone_number_1', 'phone_number_2', 'fax_1', 'fax_2', 'email_1',
#        'email_2', 'website', 'open_hours', 'latitude', 'longitude', 'facebook',
#        'twitter', 'instagram', 'pinterest', 'youtube'],
#       dtype='object')

# %%
walmart_locations_df=df.drop(columns=['name', 'url', 'phone_number_1', 'phone_number_2', 'fax_1', 'fax_2', 'email_1',
       'email_2', 'website', 'open_hours', 'facebook',
       'twitter', 'instagram', 'pinterest', 'youtube'], axis=1)

# %%
walmart_locations_df
# Out:
#               street_address           city state  zip_code country  \
# 0          1155 Hwy 65 North         Conway    AR     72032      US
# 1             1303 S Main St       Sikeston    MO     63801      US
# 2        2020 S Muskogee Ave      Tahlequah    OK     74464      US
# 3             65 Wal Mart Dr  Mountain Home    AR     72653      US
# 4     1500 S Lynn Riggs Blvd      Claremore    OK     74017      US
# ...                      ...            ...   ...       ...     ...
# 4649   12631 Broadway Street       Pearland    TX     77584      US
# 4650      1300 S Walton Blvd    Bentonville    AR     72712      US
# 4651      3701 S Highland Dr      Millcreek    UT     84106      US
# 4652           15757 Coit Rd         Dallas    TX     75248      US
# 4653  5596 S Van Winkle Expy         Murray    UT     84117      US
#
#        latitude   longitude
# 0     35.108660  -92.436905
# 1     36.857394  -89.586051
# 2     35.888765  -94.979859
# 3     36.354957  -92.341026
# ...

# %%
walmart_locations_df.isnull().sum()
# Out:
# street_address    0
# city              0
# state             0
# zip_code          0
# country           0
# latitude          0
# longitude         0
# dtype: int64

# %%
walmart_locations_df.to_csv("Resources/walmart_locations.csv")
