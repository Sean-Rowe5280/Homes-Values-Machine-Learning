# %%
# Import dependencies
import pandas as pd
import numpy as np
import plotly.express as px

# # FOR GEOPY
# from geopy.geocoders import Nominatim
# from geopy.extra.rate_limiter import RateLimiter

# For GEOPY (alternate)
import geocoder

# # FOR GOOGLE MAPS
# import googlemaps
# from config import g_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create real estate dataframe
real_estate_df=pd.read_csv("Resources/Real_Estate_Test.csv")
real_estate_df.head(11)
# Out:
#     price  bed  bath  acre_lot  \
# 0  105000    3     2      0.12
# 1   80000    4     2      0.08
# 2   67000    2     1      0.15
# 3  145000    4     2      0.10
# 4   65000    6     2      0.05
# 5  179000    4     3      0.46
# 6   50000    3     1      0.20
# 7   71600    3     2      0.08
# 8  100000    2     1      0.09
# 9  300000    5     3      7.46
#
#                                         full_address           city  \
# 0  Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601       Adjuntas
# 1            Km 78 9 Carr # 135, Adjuntas, PR, 00601       Adjuntas
# 2            556G 556-G 16 St, Juana Diaz, PR, 00795     Juana Diaz
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...          Ponce
# 4                    14 Navarro, Mayaguez, PR, 00680       Mayaguez
# 5  Bo Calabazas San Sebastian, San Sebastian, PR,...  San Sebastian
# 6                        49.1 140, Ciales, PR, 00639         Ciales
# 7                          3467 St, Ponce, PR, 00731          Ponce
# 8                  230 Rio De Vida, Ponce, PR, 00730          Ponce
# 9  Pr 120 Bo Maravilla Sur K M # 335, Las Marias,...     Las Marias
#
#          state  zip_code  house_size
# 0  Puerto Rico       601       920.0
# 1  Puerto Rico       601      1527.0
# 2  Puerto Rico       795       748.0
# 3  Puerto Rico       731      1800.0
# 4  Puerto Rico       680         NaN
# 5  Puerto Rico       612      2520.0
# 6  Puerto Rico       639      2040.0
# 7  Puerto Rico       731      1050.0
# 8  Puerto Rico       730      1092.0
# 9  Puerto Rico       670      5403.0

# %%
# For geopy (alternative)
# Geocode resource: https://towardsdatascience.com/geocoding-csv-in-python-5d45bf01694e

# Create columns to store longitude and lattitude
real_estate_df["locations"] = None
real_estate_df["longitude"] = None
real_estate_df["latitude"] = None

# Define record count and set count 
set_count = 1
record_count = 1

# Use API to add lat and long
for i in real_estate_df.index:
    
    # Keep track of amount of records
    if (i % 1000 == 0 and i >= 1000):
        set_count += 1
        record_count = 1
        
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count}")
    # Add 1 to the record count.
    record_count += 1

# Create a function to return lat / long 
def geocoding(full_address):
   g = geocoder.osm(full_address)
   return g.osm['x'], g.osm['y']

# Add lat / long to the df
locations = real_estate_df['full_address'].apply(geocoding)
real_estate_df[['longitude','latitude']] = pd.DataFrame(real_estate_df['locations'].tolist(),
                                 index=real_estate_df.index)

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1
# Processing Record 2 of Set 1
# Processing Record 3 of Set 1
# Processing Record 4 of Set 1
# Processing Record 5 of Set 1
# Processing Record 6 of Set 1
# Processing Record 7 of Set 1
# Processing Record 8 of Set 1
# Processing Record 9 of Set 1
# Processing Record 10 of Set 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14084\3992397725.py in <module>
#      31
#      32 # Add lat / long to the df
# ---> 33 locations = real_estate_df['full_address'].apply(geocoding)
#      34 real_estate_df[['longitude','latitude']] = pd.DataFrame(real_estate_df['locations'].tolist(),
#      35                                  index=real_estate_df.index)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
# -> 1101                     convert=self.convert_dtype,
#    1102                 )
#    1103
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp\ipykernel_14084\3992397725.py in geocoding(input_address)
#      28 def geocoding(input_address):
#      29    g = geocoder.osm(input_address)
# ---> 30    return g.osm['x'], g.osm['y']
#      31
#      32 # Add lat / long to the df
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Print df
real_estate_df.head(10)
